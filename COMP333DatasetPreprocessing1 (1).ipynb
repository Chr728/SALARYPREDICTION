# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## description preprocessing function and variables

# %%
def remove_emoji_andN(input_string):
    result = str(input_string).replace('\n', ' ')
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F700-\U0001F77F"
                           u"\U0001F780-\U0001F7FF"
                           u"\U0001F800-\U0001F8FF"
                           u"\U0001F900-\U0001F9FF"
                           u"\U0001FA00-\U0001FA6F"
                           u"\U0001FA70-\U0001FAFF"
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', result)

# %%
tool_keywords1 = set(['python', 'pytorch', 'sql', 'mxnet', 'mlflow', 'einstein', 'theano', 'pyspark', 'solr', 'mahout',
 'cassandra', 'aws', 'powerpoint', 'spark', 'pig', 'sas', 'java', 'nosql', 'docker', 'salesforce', 'scala', 'r',
 'c', 'c++', 'net', 'tableau', 'pandas', 'scikitlearn', 'sklearn', 'matlab', 'scala', 'keras', 'tensorflow', 'clojure',
 'caffe', 'scipy', 'numpy', 'matplotlib', 'vba', 'spss', 'linux', 'azure', 'cloud', 'gcp', 'mongodb', 'mysql', 'oracle',
 'redshift', 'snowflake', 'kafka', 'javascript', 'qlik', 'jupyter', 'perl', 'bigquery', 'unix', 'react',
 'scikit', 'powerbi', 's3', 'ec2', 'lambda', 'ssrs', 'kubernetes', 'hana', 'spacy', 'tf', 'django', 'sagemaker',
 'seaborn', 'mllib', 'github', 'git', 'elasticsearch', 'splunk', 'airflow', 'looker', 'rapidminer', 'birt', 'pentaho',
'jquery', 'nodejs', 'd3', 'plotly', 'bokeh', 'xgboost', 'rstudio', 'shiny', 'dash', 'h20', 'h2o', 'hadoop', 'mapreduce',
 'hive', 'cognos', 'angular', 'nltk', 'flask', 'node', 'firebase', 'bigtable', 'rust', 'php', 'cntk', 'lightgbm',
 'kubeflow', 'rpython', 'unixlinux', 'postgressql', 'postgresql', 'postgres', 'hbase', 'dask', 'ruby', 'julia', 'tensor',
 'dplyr','ggplot2','esquisse','bioconductor','shiny','lubridate','knitr','mlr','quanteda','dt','rcrawler','caret','rmarkdown',
 'leaflet','janitor','ggvis','plotly','rcharts','rbokeh','broom','stringr','magrittr','slidify','rvest',
 'rmysql','rsqlite','prophet','glmnet','text2vec','snowballc','quantmod','rstan','swirl','datasciencer',
                 ])

tool_keywords2 = set(['amazon web services', 'google cloud', 'sql server'])

skill_keywords1 = set(['cleansing', 'chatbot', 'cleaning', 'blockchain', 'causality', 'correlation', 'bandit', 'anomaly', 'kpi',
 'dashboard', 'geospatial', 'ocr',  'pca', 'gis', 'svm', 'svd', 'tuning', 'hyperparameter', 'hypothesis',
 'salesforcecom', 'segmentation', 'biostatistics', 'unsupervised', 'supervised', 'exploratory',
 'recommender', 'recommendations', 'research', 'sequencing', 'probability', 'reinforcement', 'graph', 'bioinformatics',
  'knn', 'etl', 'normalization', 'classification', 'optimizing', 'prediction', 'forecasting',
 'clustering', 'optimization', 'visualization', 'nlp', 'c#',
 'regression', 'logistic', 'cnn', 'glm',
 'rnn', 'lstm', 'gbm', 'boosting', 'recurrent', 'convolutional', 'bayesian',
 'bayes'])

skill_keywords2 = set(['random forest', 'natural language processing', 'machine learning', 'decision tree', 'deep learning', 'experimental design',
 'time series', 'nearest neighbors', 'neural network', 'support vector machine', 'computer vision', 'machine vision', 'dimensionality reduction',
 'text analytics', 'power bi', 'a/b testing', 'ab testing', 'chat bot', 'data mining'])

# %%
def count_skill_keywords(text, keyword_set1, keyword_set2):
    text_1 = re.sub(r'[^a-zA-Z\s]', '', text).lower().split() #for single word
    text_2 = re.sub(r'[^a-zA-Z\s]', '', text).lower() #for word combinations

    #for single word
    matching_words = set(text_1) & keyword_set1
    count_matching_words = len(matching_words)

    #for word combinations
    keyword_pattern = re.compile('|'.join(re.escape(keyword) for keyword in keyword_set2))
    matches = keyword_pattern.findall(text_2)

    return len(set(matches)) + count_matching_words

# %% [markdown]
# ## Key word preprocessing for the merged dataset

# %% [markdown]
# ### To see the frequency of each key word in the whole combined description

# %%
skill_keywords = skill_keywords1.union(skill_keywords2)
skill_word_counts = {word: merged_df['Description'].str.count(word).sum() for word in skill_keywords}

skill_keyword_freq = pd.DataFrame(list(word_counts.items()), columns=['skill_keyword_freq', 'Count'])

print(skill_keyword_freq)

tool_keywords = tool_keywords1.union(tool_keywords2)
tool_word_counts = {word: merged_df['Description'].str.count(word).sum() for word in tool_keywords}

tool_keyword_freq = pd.DataFrame(list(word_counts.items()), columns=['tool_keyword_freq', 'Count'])

print(tool_keyword_freq)

# %% [markdown]
# ### To calculate the frequency of a single keyword for each row:

# %%
total_keywords = tool_keywords.union(skill_keywords)

for keyword in total_keywords:
    merged_df[keyword] = merged_df['Description'].apply(lambda x: x.lower().count(keyword.lower()))

print(merged_df)

# %% [markdown]
# ### To check the correlation

# %%
merged_df_2 = merged_df.drop(['Description', 'Title', 'Company Name', 'City', 'State'], axis=1)

salary_column = merged_df_2['Salary']
correlations = merged_df_2.corrwith(salary_column)


sorted_correlations = correlations.abs().sort_values(ascending=False)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(sorted_correlations)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %% [markdown]
# ## Jobspikr dataset

# %% [markdown]
# This dataset contains exclusively data science jobs from 2019

# %%
Jobspikr = pd.read_csv('/Users/chris/Downloads/datasets/datasets/data_scientist_united_states_job_postings_jobspikr.csv', engine='python')

# %%
# Drop rows with missing values in specified columns
Jobspikr = Jobspikr.dropna(subset=['salary_offered', 'city', 'state'])

# Filter by job type
Jobspikr = Jobspikr[Jobspikr['job_type'] == 'Full Time']

# Select relevant columns
Jobspikr = Jobspikr[['job_title', 'job_description', 'company_name', 'city', 'state', 'post_date', 'salary_offered']]

# Define a regular expression pattern for salary extraction
salary_pattern = r'\$([\d,]+)[Kk]?\s*-\s*\$([\d,]+)[Kk]?'

# Extract and preprocess salaries
def process_salary_string(salary_str):
    match = re.search(salary_pattern, salary_str)
    if match:
        lower_salary, upper_salary = map(lambda x: float(x.replace(',', '')), match.groups())
    else:
        numeric_values = [float(val.replace(',', '')) for val in re.findall(r'\b[\d,]+\b', salary_str)][:2]
        lower_salary, upper_salary = numeric_values if len(numeric_values) == 2 else (None, None)
    return lower_salary, upper_salary

# Apply the function to extract and preprocess salaries
Jobspikr['lower_salary'], Jobspikr['upper_salary'] = zip(*Jobspikr['salary_offered'].map(process_salary_string))

# Create a new column 'approximated_salary'
Jobspikr['approximated_salary'] = Jobspikr[['lower_salary', 'upper_salary']].mean(axis=1).apply(lambda x: int(str(x).split('.')[0][:3]) if pd.notna(x) else x)

# Drop unnecessary columns
Jobspikr = Jobspikr.drop(columns=['salary_offered', 'lower_salary', 'upper_salary'])

# Drop rows with missing values in the new column
Jobspikr = Jobspikr.dropna(subset=['approximated_salary'])

# Convert 'post_date' to datetime format
Jobspikr['post_date'] = pd.to_datetime(Jobspikr['post_date'])

# Extract year, month, and day into separate columns
Jobspikr[['year', 'month', 'day']] = Jobspikr['post_date'].apply(lambda x: pd.Series([x.year, x.month, x.day]))

# Drop the original 'post_date' column
Jobspikr = Jobspikr.drop(columns=['post_date'])


# Rename columns
Jobspikr = Jobspikr.rename(columns={
    'job_title': 'Title',
    'job_description': 'Description',
    'company_name': 'Company Name',
    'city': 'City',
    'state': 'State',
    'year': 'Year',
    'month': 'Month',
    'day': 'Day',
    'approximated_salary': 'Salary'
}).reset_index(drop=True)

Jobspikr['Salary'] = (Jobspikr['Salary'] * 1000).round()

# %%
Jobspikr
# Out:
#                                                  Title  \
# 0    Data Scientist - Cross Asset Desk Strategist T...
# 1    Senior Data Scientist - Infectious Disease and...
# 2    Senior Data Scientist, Advanced Marketing Anal...
# 3                  TV Data Scientist in Burlington, MA
# 4                  TV Data Scientist in Burlington, MA
# ..                                                 ...
# 574                     Data Scientist in Columbus, OH
# 575                     Data Scientist in Columbus, OH
# 576                    Data Scientist in Arlington, VA
# 577  Staff Engineer, Data Scientist in Mountain Vie...
# 578                Senior Data Scientist in Reston, VA
#
#                                            Description  \
# 0    DESCRIPTION Morgan Stanley's business around t...
# 1    Job Req ID: 204549 Position Number: 00167522 E...
# 2    Spotify is seeking a Senior Data Scientist to ...
# 3    Our services power people-based customer exper...
# 4    ABOUT THIS JOB TV is one of the key growth are...
# ..                                                 ...
# 574  Description As the Data Scientist, you will wo...
# 575  Description As the Data Scientist, you will wo...
# 576  Data Scientist A Data Science firm in the D.C....
# 577  Artificial intelligence is revolutionizing the...
# 578  Bechtel Corporation is seeking a talented and ...
#
#                      Company Name           City State  Salary  Year  Month  \
# 0                  Morgan Stanley       New York    NY   90000  2019      8
# 1     Carolinas HealthCare System      Charlotte    NC  125000  2019      9
# 2                         Spotify       New York    NY  125000  2019      8
# 3                        LiveRamp     Burlington    MA  125000  2019      8
# 4                        LiveRamp     Burlington    MA  125000  2019      8
# ..                            ...            ...   ...     ...   ...    ...
# 574      Citizens Financial Group       Columbus    OH   90000  2019      9
# 575      Citizens Financial Group       Columbus    OH   90000  2019      9
# 576                     Jobspring      Arlington    VA  115000  2019      9
# 577                      Omnicell  Mountain View    CA  175000  2019      9
# 578  Bechtel Plant Machinery, Inc         Reston    VA  125000  2019      9
#
#      Day
# 0     20
# 1      6
# 2     23
# 3      2
# 4      2
# ..   ...
# 574   28
# 575   28
# 576   28
# 577   27
# 578   28
#
# [579 rows x 9 columns]

# %% [markdown]
# ### Description Preprocessing

# %%
Jobspikr['description'] = Jobspikr['Title'] + ' ' + Jobspikr['Description']
Jobspikr = Jobspikr.drop(['Description'], axis=1)

# %%
Jobspikr['description'] = Jobspikr['description'].map(remove_emoji_andN)

# %%
Jobspikr['skill_keywords'] = Jobspikr.apply(lambda row: count_skill_keywords(row['description'], skill_keywords1, skill_keywords2), axis=1)
Jobspikr['tool_keywords'] = Jobspikr.apply(lambda row: count_skill_keywords(row['description'], tool_keywords1, tool_keywords2), axis=1)

# %%
Jobspikr = Jobspikr[['Title', 'description', 'Company Name', 'City', 'State', 'Salary', 'Year', 'Month', 'Day', 'skill_keywords', 'tool_keywords']]
fix_description_column_name= {
    'description': 'Description',
}
Jobspikr = Jobspikr.rename(columns=fix_description_column_name)
Jobspikr
# Out:
#                                                  Title  \
# 0    Data Scientist - Cross Asset Desk Strategist T...
# 1    Senior Data Scientist - Infectious Disease and...
# 2    Senior Data Scientist, Advanced Marketing Anal...
# 3                  TV Data Scientist in Burlington, MA
# 4                  TV Data Scientist in Burlington, MA
# ..                                                 ...
# 574                     Data Scientist in Columbus, OH
# 575                     Data Scientist in Columbus, OH
# 576                    Data Scientist in Arlington, VA
# 577  Staff Engineer, Data Scientist in Mountain Vie...
# 578                Senior Data Scientist in Reston, VA
#
#                                            Description  \
# 0    Data Scientist - Cross Asset Desk Strategist T...
# 1    Senior Data Scientist - Infectious Disease and...
# 2    Senior Data Scientist, Advanced Marketing Anal...
# 3    TV Data Scientist in Burlington, MA Our servic...
# 4    TV Data Scientist in Burlington, MA ABOUT THIS...
# ..                                                 ...
# 574  Data Scientist in Columbus, OH Description As ...
# 575  Data Scientist in Columbus, OH Description As ...
# 576  Data Scientist in Arlington, VA Data Scientist...
# 577  Staff Engineer, Data Scientist in Mountain Vie...
# 578  Senior Data Scientist in Reston, VA Bechtel Co...
#
#                      Company Name           City State  Salary  Year  Month  \
# 0                  Morgan Stanley       New York    NY   90000  2019      8
# 1     Carolinas HealthCare System      Charlotte    NC  125000  2019      9
# 2                         Spotify       New York    NY  125000  2019      8
# 3                        LiveRamp     Burlington    MA  125000  2019      8
# 4                        LiveRamp     Burlington    MA  125000  2019      8
# ..                            ...            ...   ...     ...   ...    ...
# 574      Citizens Financial Group       Columbus    OH   90000  2019      9
# 575      Citizens Financial Group       Columbus    OH   90000  2019      9
# 576                     Jobspring      Arlington    VA  115000  2019      9
# 577                      Omnicell  Mountain View    CA  175000  2019      9
# 578  Bechtel Plant Machinery, Inc         Reston    VA  125000  2019      9
#
#      Day  skill_keywords  tool_keywords
# 0     20               2              1
# 1      6               4              2
# 2     23               7              5
# 3      2               6              8
# 4      2               6              8
# ..   ...             ...            ...
# 574   28               7              0
# 575   28               7              0
# 576   28               3              6
# 577   27               7              3
# 578   28              10              7
#
# [579 rows x 11 columns]

# %% [markdown]
# ## Glassdoor dataset

# %% [markdown]
# Data Science Job Posting on Glassdoor. Job post years are not available.

# %%
Glassdoor = pd.read_csv('/Users/chris/Downloads/datasets/datasets/Data Science Job Posting on Glassdoor/Uncleaned_DS_jobs.csv', engine='python')

# %%
Glassdoor
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#                   Company Name           Location            Headquarters  \
# 0             Healthfirst\n3.1       New York, NY            New York, NY
# 1                 ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2          Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                 INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions\n2.9       New York, NY            New York, NY
# ..                         ...                ...                     ...
# 667              TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                       JKGT  San Francisco, CA                      -1
# 669                 AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1       -1                       -1
# 669                       -1       -1                       -1
# 670        1 to 50 employees       -1        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  \
# 0      Unknown / Non-Applicable
# 1        $1 to $2 billion (USD)
# 2    $100 to $500 million (USD)
# 3    $100 to $500 million (USD)
# 4      Unknown / Non-Applicable
# ..                          ...
# 667    Unknown / Non-Applicable
# 668                          -1
# 669                          -1
# 670      $1 to $5 million (USD)
# 671      $1 to $2 billion (USD)
#
#                                            Competitors
# 0              EmblemHealth, UnitedHealth Group, Aetna
# 1                                                   -1
# 2                                                   -1
# 3    MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 667                                                 -1
# 668                                                 -1
# 669                                                 -1
# 670                                                 -1
# 671                                                 -1
#
# [672 rows x 15 columns]

# %%
# Drop rows with missing values in specified columns
Glassdoor = Glassdoor.dropna(subset=['Salary Estimate', 'Location', 'Company Name'])

# Define a regular expression pattern for salary extraction
salary_pattern = r'\$([\d,]+)[Kk]?\s*-\s*\$([\d,]+)[Kk]?'

# Extract and preprocess salaries
def process_salary_string(salary_str):
    match = re.search(salary_pattern, salary_str)
    if match:
        lower_salary, upper_salary = map(lambda x: float(x.replace(',', '')), match.groups())
    else:
        numeric_values = [float(val.replace(',', '')) for val in re.findall(r'\b[\d,]+\b', salary_str)][:2]
        lower_salary, upper_salary = numeric_values if len(numeric_values) == 2 else (None, None)
    return lower_salary, upper_salary

# Apply the function to extract and preprocess salaries
Glassdoor['lower_salary'], Glassdoor['upper_salary'] = zip(*Glassdoor['Salary Estimate'].map(process_salary_string))

# Create a new column 'approximated_salary'
Glassdoor['approximated_salary'] = Glassdoor[['lower_salary', 'upper_salary']].mean(axis=1).apply(lambda x: int(str(x).split('.')[0][:3]) if pd.notna(x) else x)

# Drop unnecessary columns
Glassdoor = Glassdoor.drop(columns=['Salary Estimate', 'lower_salary', 'upper_salary'])

# Drop rows with missing values in the new column
Glassdoor = Glassdoor.dropna(subset=['approximated_salary'])

# Reset the index to have consecutive indices
Glassdoor = Glassdoor.reset_index(drop=True)

# Select relevant columns
Glassdoor = Glassdoor[['Job Title', 'Job Description', 'Company Name', 'Location','approximated_salary']]

# Split 'Location' into 'City' and 'State' columns
location_split = Glassdoor['Location'].str.split(', ', expand=True)
Glassdoor['City'] = location_split[0]
Glassdoor['State'] = location_split[1]
Glassdoor = Glassdoor.dropna(subset=['State'])

# Drop the original 'Location' column
Glassdoor = Glassdoor.drop(columns=['Location'])

# Rename columns
Glassdoor = Glassdoor.rename(columns={
    'Job Title': 'Title',
    'Job Description': 'Description',
    'city': 'City',
    'state': 'State',
    'year': 'Year',
    'approximated_salary': 'Salary'
}).reset_index(drop=True)

# Add columns filled with NaN
Glassdoor['Year'] = np.nan
Glassdoor['Month'] = np.nan
Glassdoor['Day'] = np.nan

# Convert columns to Int64 type
Glassdoor['Year'] = Glassdoor['Year'].astype('Int64')
Glassdoor['Month'] = Glassdoor['Month'].astype('Int64')
Glassdoor['Day'] = Glassdoor['Day'].astype('Int64')
Glassdoor['Salary'] = Glassdoor['Salary'].astype('Int64')

# Reorder columns to match the specified order
column_order = ['Title', 'Description', 'Company Name', 'City', 'State', 'Salary', 'Year', 'Month', 'Day']
Glassdoor = Glassdoor[column_order]
Glassdoor['Salary'] = Glassdoor['Salary'].apply(lambda x: x*1000)

# %%
Glassdoor
# Out:
#                  Title                                        Description  \
# 0    Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1       Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2       Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3       Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4       Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
# ..                 ...                                                ...
# 644     Data Scientist  Summary\n\nWe’re looking for a data scientist ...
# 645     Data Scientist  Job Description\nBecome a thought leader withi...
# 646     Data Scientist  Join a thriving company that is changing the w...
# 647     Data Scientist  100 Remote Opportunity As an AINLP Data Scient...
# 648     Data Scientist  Description\n\nThe Data Scientist will be part...
#
#                   Company Name           City State  Salary  Year  Month   Day
# 0             Healthfirst\n3.1       New York    NY  154000  <NA>   <NA>  <NA>
# 1                 ManTech\n4.2      Chantilly    VA  154000  <NA>   <NA>  <NA>
# 2          Analysis Group\n3.8         Boston    MA  154000  <NA>   <NA>  <NA>
# 3                 INFICON\n3.5         Newton    MA  154000  <NA>   <NA>  <NA>
# 4      Affinity Solutions\n2.9       New York    NY  154000  <NA>   <NA>  <NA>
# ..                         ...            ...   ...     ...   ...    ...   ...
# 644              TRANZACT\n3.6       Fort Lee    NJ  136000  <NA>   <NA>  <NA>
# 645                       JKGT  San Francisco    CA  136000  <NA>   <NA>  <NA>
# 646                 AccessHope      Irwindale    CA  136000  <NA>   <NA>  <NA>
# 647  ChaTeck Incorporated\n5.0  San Francisco    CA  136000  <NA>   <NA>  <NA>
# 648         1-800-Flowers\n2.7       New York    NY  136000  <NA>   <NA>  <NA>
#
# [649 rows x 9 columns]

# %% [markdown]
# ### Description Preprocessing

# %%
Glassdoor['description'] = Glassdoor['Title'] + ' ' + Glassdoor['Description']
Glassdoor = Glassdoor.drop(['Description'], axis=1)

# %%
Glassdoor['Company Name'] = Glassdoor['Company Name'].map(lambda x: x.split('\n')[0])

# %%
Glassdoor['description'] = Glassdoor['description'].map(remove_emoji_andN)

# %%
Glassdoor['skill_keywords'] = Glassdoor.apply(lambda row: count_skill_keywords(row['description'], skill_keywords1, skill_keywords2), axis=1)
Glassdoor['tool_keywords'] = Glassdoor.apply(lambda row: count_skill_keywords(row['description'], tool_keywords1, tool_keywords2), axis=1)

# %%
Glassdoor = Glassdoor[['Title', 'description', 'Company Name', 'City', 'State', 'Salary', 'Year', 'Month', 'Day', 'skill_keywords', 'tool_keywords']]
fix_description_column_name= {
    'description': 'Description',
}
Glassdoor = Glassdoor.rename(columns=fix_description_column_name)
Glassdoor
# Out:
#                  Title                                        Description  \
# 0    Sr Data Scientist  Sr Data Scientist Description  The Senior Data...
# 1       Data Scientist  Data Scientist Secure our Nation, Ignite your ...
# 2       Data Scientist  Data Scientist Overview   Analysis Group is on...
# 3       Data Scientist  Data Scientist JOB DESCRIPTION:  Do you have a...
# 4       Data Scientist  Data Scientist Data Scientist Affinity Solutio...
# ..                 ...                                                ...
# 644     Data Scientist  Data Scientist Summary  We’re looking for a da...
# 645     Data Scientist  Data Scientist Job Description Become a though...
# 646     Data Scientist  Data Scientist Join a thriving company that is...
# 647     Data Scientist  Data Scientist 100 Remote Opportunity As an AI...
# 648     Data Scientist  Data Scientist Description  The Data Scientist...
#
#              Company Name           City State  Salary  Year  Month   Day  \
# 0             Healthfirst       New York    NY  154000  <NA>   <NA>  <NA>
# 1                 ManTech      Chantilly    VA  154000  <NA>   <NA>  <NA>
# 2          Analysis Group         Boston    MA  154000  <NA>   <NA>  <NA>
# 3                 INFICON         Newton    MA  154000  <NA>   <NA>  <NA>
# 4      Affinity Solutions       New York    NY  154000  <NA>   <NA>  <NA>
# ..                    ...            ...   ...     ...   ...    ...   ...
# 644              TRANZACT       Fort Lee    NJ  136000  <NA>   <NA>  <NA>
# 645                  JKGT  San Francisco    CA  136000  <NA>   <NA>  <NA>
# 646            AccessHope      Irwindale    CA  136000  <NA>   <NA>  <NA>
# 647  ChaTeck Incorporated  San Francisco    CA  136000  <NA>   <NA>  <NA>
# 648         1-800-Flowers       New York    NY  136000  <NA>   <NA>  <NA>
#
#      skill_keywords  tool_keywords
# 0                 8              3
# 1                 7              2
# 2                 8              6
# 3                 6              5
# 4                 4              7
# ..              ...            ...
# 644               9              4
# 645               2              0
# 646               6              8
# 647               8             16
# 648               2              4
#
# [649 rows x 11 columns]

# %% [markdown]
# ## AI jobs dataset

# %%
AI_jobs = pd.read_csv('/Users/chris/Downloads/datasets/datasets/final_ai_jobs.csv', engine='python')

# %%
AI_jobs
# Out:
#                                               job_link  \
# 0    https://www.indeed.com/rc/clk?jk=3a9047b41601a...
# 1    https://www.indeed.com/rc/clk?jk=b1b60d57adfbb...
# 2    https://www.indeed.com/rc/clk?jk=a0f33cc71b175...
# 3    https://www.indeed.com/rc/clk?jk=ac4bbf72deed7...
# 4    https://www.indeed.com/rc/clk?jk=7f8e658852335...
# ..                                                 ...
# 254  https://www.indeed.com/rc/clk?jk=c10185f43bfe5...
# 255  https://www.indeed.com/rc/clk?jk=ba5f975dfc58e...
# 256  https://www.indeed.com/rc/clk?jk=1159bda5377f5...
# 257  https://www.indeed.com/rc/clk?jk=9f3c536884566...
# 258  https://www.indeed.com/rc/clk?jk=f45fa5b3a9d7a...
#
#                                              job_title       company_name  \
# 0           UX Researcher, Qualitative - Generative AI               Meta
# 1    Fundamental Language Research Scientist - Gene...               Meta
# 2              Data Scientist, Product - Generative AI       Facebook App
# 3                     Product Designer - Generative AI               Meta
# 4    Director, Product Technical Program Management...               Meta
# ..                                                 ...                ...
# 254                     Research Engineer - Multimodal       Character.AI
# 255                              Systems Administrator  SambaNova Systems
# 256                              Growth Marketing Lead      Fitmate Coach
# 257                               HC Account Executive               Hyro
# 258             Senior ASIC Design Automation Engineer  SambaNova Systems
#
#       company_location         salary       job_type         rating  \
# 0         New York, NY         184500      Full-time            4.1
# 1         New York, NY         173500  Not available            4.1
# 2         New York, NY         164000  Not available            4.1
# 3         New York, NY         158000  Not available            4.1
# 4         New York, NY         265000  Not available            4.1
# ..                 ...            ...            ...            ...
# 254      Palo Alto, CA  Not available      Full-time            4.2
# 255      Palo Alto, CA         125000  Not available  Not available
# 256  San Francisco, CA         137000      Full-time  Not available
# 257        Oakland, CA         250000  Not available  Not available
# 258      Palo Alto, CA         125000  Not available  Not available
#
#                                        job_description   searched_job  \
# 0    Work closely with product and business teams t...  Generative AI
# 1    Direct experience in responsible ,, , ,, and L...  Generative AI
# 2    You will collaborate on a wide array of produc...  Generative AI
# 3    We utilize a full range of product design skil...  Generative AI
# 4    We are uniquely positioned to adopt an end-to-...  Generative AI
# ..                                                 ...            ...
# 254  Have experience with , models for various moda...  Generative AI
# 255  Your work will directly impact employees, cust...  Generative AI
# 256  Our unique solution tackles people’s main prob...  Generative AI
# 257  Hyro’s conversational , platform turns complex...  Generative AI
# 258  SambaNova is hiring a Senior ASIC Design Autom...  Generative AI
#
#     searched_location
# 0            New York
# 1            New York
# 2            New York
# 3            New York
# 4            New York
# ..                ...
# 254     San Francisco
# 255     San Francisco
# 256     San Francisco
# 257     San Francisco
# 258     San Francisco
#
# [259 rows x 10 columns]

# %%
# Drop rows with missing values in specified columns
AI_jobs = AI_jobs[['job_title', 'job_description', 'company_name', 'company_location', 'salary']]

# Split 'Location' into 'City' and 'State' columns
location_split = AI_jobs['company_location'].str.split(', ', expand=True)
AI_jobs['City'] = location_split[0]
AI_jobs['State'] = location_split[1]
AI_jobs = AI_jobs.dropna(subset=['State'])

# Drop the original 'Location' column
AI_jobs = AI_jobs.drop(columns=['company_location'])

#AI_jobs = AI_jobs['salary'] / 100000

# Rename columns
AI_jobs = AI_jobs.rename(columns={
    'job_title': 'Title',
    'job_description': 'Description',
    'company_name': 'Company Name',
    'salary': 'Salary'
}).reset_index(drop=True)

# Add columns filled with NaN
AI_jobs['Year'] = np.nan
AI_jobs['Month'] = np.nan
AI_jobs['Day'] = np.nan

# Remove rows where the salary is 'Not available'
AI_jobs = AI_jobs[AI_jobs['Salary'] != 'Not available']


# Convert columns to Int64 type
AI_jobs['Year'] = AI_jobs['Year'].astype('Int64')
AI_jobs['Month'] = AI_jobs['Month'].astype('Int64')
AI_jobs['Day'] = AI_jobs['Day'].astype('Int64')
AI_jobs['Salary'] = AI_jobs['Salary'].astype('float32').fillna(0).astype('int64')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_28456\2557656609.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AI_jobs['City'] = location_split[0]
# C:\Users\chris\AppData\Local\Temp\ipykernel_28456\2557656609.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AI_jobs['State'] = location_split[1]

# %%
print(AI_jobs['Salary'].dtype)
# Out:
# int64

# %%
AI_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 0 to 250
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         198 non-null    object
#  1   Description   198 non-null    object
#  2   Company Name  198 non-null    object
#  3   Salary        198 non-null    int64
#  4   City          198 non-null    object
#  5   State         198 non-null    object
#  6   Year          0 non-null      Int64
#  7   Month         0 non-null      Int64
#  8   Day           0 non-null      Int64
# dtypes: Int64(3), int64(1), object(5)
# memory usage: 16.0+ KB

# %%
AI_jobs
# Out:
#                                                  Title  \
# 0           UX Researcher, Qualitative - Generative AI
# 1    Fundamental Language Research Scientist - Gene...
# 2              Data Scientist, Product - Generative AI
# 3                     Product Designer - Generative AI
# 4    Director, Product Technical Program Management...
# ..                                                 ...
# 244                                  Founding Designer
# 247                              Systems Administrator
# 248                              Growth Marketing Lead
# 249                               HC Account Executive
# 250             Senior ASIC Design Automation Engineer
#
#                                            Description       Company Name  \
# 0    Work closely with product and business teams t...               Meta
# 1    Direct experience in responsible ,, , ,, and L...               Meta
# 2    You will collaborate on a wide array of produc...       Facebook App
# 3    We utilize a full range of product design skil...               Meta
# 4    We are uniquely positioned to adopt an end-to-...               Meta
# ..                                                 ...                ...
# 244  Create's customers launch fully functional sof...             Create
# 247  Your work will directly impact employees, cust...  SambaNova Systems
# 248  Our unique solution tackles people’s main prob...      Fitmate Coach
# 249  Hyro’s conversational , platform turns complex...               Hyro
# 250  SambaNova is hiring a Senior ASIC Design Autom...  SambaNova Systems
#
#      Salary           City     State  Year  Month   Day
# 0    184500       New York        NY  <NA>   <NA>  <NA>
# 1    173500       New York        NY  <NA>   <NA>  <NA>
# 2    164000       New York        NY  <NA>   <NA>  <NA>
# 3    158000       New York        NY  <NA>   <NA>  <NA>
# 4    265000       New York        NY  <NA>   <NA>  <NA>
# ..      ...            ...       ...   ...    ...   ...
# 244  145000  San Francisco  CA 94103  <NA>   <NA>  <NA>
# 247  125000      Palo Alto        CA  <NA>   <NA>  <NA>
# 248  137000  San Francisco        CA  <NA>   <NA>  <NA>
# 249  250000        Oakland        CA  <NA>   <NA>  <NA>
# 250  125000      Palo Alto        CA  <NA>   <NA>  <NA>
#
# [198 rows x 9 columns]

# %% [markdown]
# ### Description preprocessing

# %%
AI_jobs['description'] = AI_jobs['Title'] + ' ' + AI_jobs['Description']
AI_jobs = AI_jobs.drop(['Description'], axis=1)

# %%
AI_jobs['description'] = AI_jobs['description'].map(remove_emoji_andN)

# %%
AI_jobs['skill_keywords'] = AI_jobs.apply(lambda row: count_skill_keywords(row['description'], skill_keywords1, skill_keywords2), axis=1)
AI_jobs['tool_keywords'] = AI_jobs.apply(lambda row: count_skill_keywords(row['description'], tool_keywords1, tool_keywords2), axis=1)

# %%
AI_jobs = AI_jobs[['Title', 'description', 'Company Name', 'City', 'State', 'Salary', 'Year', 'Month', 'Day', 'skill_keywords', 'tool_keywords']]
fix_description_column_name= {
    'description': 'Description',
}
AI_jobs = AI_jobs.rename(columns=fix_description_column_name)
AI_jobs
# Out:
#                                                  Title  \
# 0           UX Researcher, Qualitative - Generative AI
# 1    Fundamental Language Research Scientist - Gene...
# 2              Data Scientist, Product - Generative AI
# 3                     Product Designer - Generative AI
# 4    Director, Product Technical Program Management...
# ..                                                 ...
# 244                                  Founding Designer
# 247                              Systems Administrator
# 248                              Growth Marketing Lead
# 249                               HC Account Executive
# 250             Senior ASIC Design Automation Engineer
#
#                                            Description       Company Name  \
# 0    UX Researcher, Qualitative - Generative AI Wor...               Meta
# 1    Fundamental Language Research Scientist - Gene...               Meta
# 2    Data Scientist, Product - Generative AI You wi...       Facebook App
# 3    Product Designer - Generative AI We utilize a ...               Meta
# 4    Director, Product Technical Program Management...               Meta
# ..                                                 ...                ...
# 244  Founding Designer Create's customers launch fu...             Create
# 247  Systems Administrator Your work will directly ...  SambaNova Systems
# 248  Growth Marketing Lead Our unique solution tack...      Fitmate Coach
# 249  HC Account Executive Hyro’s conversational , p...               Hyro
# 250  Senior ASIC Design Automation Engineer SambaNo...  SambaNova Systems
#
#               City     State  Salary  Year  Month   Day  skill_keywords  \
# 0         New York        NY  184500  <NA>   <NA>  <NA>               1
# 1         New York        NY  173500  <NA>   <NA>  <NA>               2
# 2         New York        NY  164000  <NA>   <NA>  <NA>               1
# 3         New York        NY  158000  <NA>   <NA>  <NA>               0
# 4         New York        NY  265000  <NA>   <NA>  <NA>               0
# ..             ...       ...     ...   ...    ...   ...             ...
# 244  San Francisco  CA 94103  145000  <NA>   <NA>  <NA>               0
# 247      Palo Alto        CA  125000  <NA>   <NA>  <NA>               0
# 248  San Francisco        CA  137000  <NA>   <NA>  <NA>               0
# 249        Oakland        CA  250000  <NA>   <NA>  <NA>               0
# 250      Palo Alto        CA  125000  <NA>   <NA>  <NA>               0
#
#      tool_keywords
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 244              0
# 247              0
# 248              0
# 249              0
# 250              0
#
# [198 rows x 11 columns]

# %% [markdown]
# ## LinkedIn Dataset

# %%
LinkedIn = pd.read_csv('/Users/chris/Downloads/datasets/datasets/LinkedIn Job Postings - 2023/job_postings.csv', engine='python')
company_id = pd.read_csv('/Users/chris/Downloads/datasets/datasets/LinkedIn Job Postings - 2023/company_details/companies.csv', engine='python')

# %%
LinkedIn = pd.merge(LinkedIn , company_id, on='company_id', how='inner')
LinkedIn.head(1)
# Out:
#        job_id  company_id                  title  \
# 0  3757940104    553718.0  Hearing Care Provider
#
#                                        description_x  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN      5250.0
#
#    min_salary pay_period formatted_work_type          location  ...  \
# 0         NaN    MONTHLY           Full-time  Little River, SC  ...
#
#       scraped         name                                      description_y  \
# 0  1699138101  HearingLife  HearingLife is a national hearing care company...
#
#    company_size       state country      city  zip_code            address  \
# 0           5.0  New Jersey      US  Somerset     08873  580 Howard Avenue
#
#                                              url
# 0  https://www.linkedin.com/company/hearing-life
#
# [1 rows x 37 columns]

# %%
LinkedIn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32545 entries, 0 to 32544
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      32545 non-null  int64
#  1   company_id                  32545 non-null  float64
#  2   title                       32545 non-null  object
#  3   description_x               32544 non-null  object
#  4   max_salary                  10905 non-null  float64
#  5   med_salary                  2211 non-null   float64
#  6   min_salary                  10905 non-null  float64
#  7   pay_period                  13116 non-null  object
#  8   formatted_work_type         32545 non-null  object
#  9   location                    32545 non-null  object
#  10  applies                     15871 non-null  float64
#  11  original_listed_time        32545 non-null  float64
#  12  remote_allowed              4665 non-null   float64
#  13  views                       25290 non-null  float64
#  14  job_posting_url             32545 non-null  object
#  15  application_url             20957 non-null  object
#  16  application_type            32545 non-null  object
#  17  expiry                      32545 non-null  float64
#  18  closed_time                 1149 non-null   float64
#  19  formatted_experience_level  23957 non-null  object
#  20  skills_desc                 336 non-null    object
#  21  listed_time                 32545 non-null  float64
#  22  posting_domain              19684 non-null  object
#  23  sponsored                   32545 non-null  int64
#  24  work_type                   32545 non-null  object
#  25  currency                    13116 non-null  object
#  26  compensation_type           13116 non-null  object
#  27  scraped                     32545 non-null  int64
#  28  name                        32541 non-null  object
#  29  description_y               32356 non-null  object
#  30  company_size                31096 non-null  float64
#  31  state                       32534 non-null  object
#  32  country                     32545 non-null  object
#  33  city                        32544 non-null  object
#  34  zip_code                    32529 non-null  object
#  35  address                     32528 non-null  object
#  36  url                         32545 non-null  object
# dtypes: float64(12), int64(3), object(22)
# memory usage: 9.4+ MB

# %%
# Filter by job type
LinkedIn = LinkedIn[LinkedIn['formatted_work_type'] == 'Full-time']
LinkedIn = LinkedIn[LinkedIn['work_type'] == 'FULL_TIME']

def convert_to_yearly(row):
    if row['pay_period'] == 'MONTHLY':
        return row['med_salary'] * 12
    elif row['pay_period'] == 'HOURLY':
        # Assuming 40 hours per week and 52 weeks per year
        return row['med_salary'] * 40 * 52
    else:
        return row['med_salary']

# Use the conversion function to create a new 'med_salary' column
LinkedIn['med_salary'] = LinkedIn.apply(convert_to_yearly, axis=1)


LinkedIn = LinkedIn[['title', 'description_x', 'description_y', 'name', 'city', 'min_salary', 'med_salary', 'max_salary', 'state', 'original_listed_time']]
LinkedIn
# Out:
#                                                    title  \
# 0                                  Hearing Care Provider
# 1                               Patient Care Coordinator
# 2      Shipping & Receiving Associate 2nd shift (Beav...
# 3                         Vice President of Supply Chain
# 4                                   Manager, Engineering
# ...                                                  ...
# 32540                                NY Studio Assistant
# 32541                                   Business Manager
# 32542                                      Sales Manager
# 32543                                    Franchise Owner
# 32544                                   Stylist/ Clorist
#
#                                            description_x  \
# 0      Overview\n\nHearingLife is a national hearing ...
# 1      Overview\n\nWho WE Are: \n\nHearingLife is a D...
# 2      Metalcraft of Mayville\nMetalcraft of Mayville...
# 3      Metalcraft of Mayville\nMetalcraft of Mayville...
# 4      \nThe TSUBAKI name is synonymous with excellen...
# ...                                                  ...
# 32540  YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...
# 32541  Business ManagerFirst Baptist Church ForneyFor...
# 32542  Are you a dynamic and creative marketing profe...
# 32543  DuctVentz is a dryer and A/C – heat vent clean...
# 32544  Karen Marie is looking for an awesome experien...
#
#                                            description_y  \
# 0      HearingLife is a national hearing care company...
# 1      HearingLife is a national hearing care company...
# 2      Headquartered in Mayville, Wisconsin, Metalcra...
# 3      Headquartered in Mayville, Wisconsin, Metalcra...
# 4      U.S. Tsubaki Power Transmission, LLC is a subs...
# ...                                                  ...
# 32540  Ken Fulk Inc, is a creative think tank based o...
# 32541                                                NaN
# 32542  CargoLogin is a freight and logistics company ...
# 32543  DryerVentz operates, manages and markets Dryer...
# 32544  Hair salon & in Bucktown! Specializing in colo...
#
#                                        name           city  min_salary  \
# 0                               HearingLife       Somerset         NaN
# 1                               HearingLife       Somerset         NaN
# 2              Metalcraft of Mayville, Inc.       Mayville         NaN
# 3              Metalcraft of Mayville, Inc.       Mayville         NaN
# 4      U.S. Tsubaki Power Transmission, LLC       Wheeling         NaN
# ...                                     ...            ...         ...
# 32540                          Ken Fulk Inc  San Francisco         NaN
# 32541           First Baptist Church Forney         Forney         NaN
# 32542                           CargoLogin.  Santa Clarita         NaN
# 32543                DryerVentz - DuctVentz       New York         NaN
# 32544                     Karen Marie Salon        Chicago     35000.0
#
#        med_salary  max_salary       state  original_listed_time
# 0         63000.0         NaN  New Jersey          1.699090e+12
# 1         63000.0         NaN  New Jersey          1.699060e+12
# 2             NaN         NaN          WI          1.699080e+12
# 3             NaN         NaN          WI          1.699080e+12
# 4             NaN         NaN    Illinois          1.699080e+12
# ...           ...         ...         ...                   ...
# 32540         NaN         NaN  California          1.692870e+12
# 32541         NaN         NaN       Texas          1.692830e+12
# 32542         NaN         NaN  California          1.692830e+12
# 32543         NaN         NaN           0          1.699050e+12
# 32544         NaN     80000.0    Illinois          1.699050e+12
#
# [26345 rows x 10 columns]

# %% [markdown]
# ### Description preprocessing:

# %%
LinkedIn['description'] = LinkedIn['description_x'] + ' ' +LinkedIn['description_y'] + ' ' +LinkedIn['title']
LinkedIn = LinkedIn.drop(['description_y', 'description_x'], axis=1)

# %%
LinkedIn['description'] = LinkedIn['description'].map(remove_emoji_andN)

# %%
LinkedIn['skill_keywords'] = LinkedIn.apply(lambda row: count_skill_keywords(row['description'], skill_keywords1, skill_keywords2), axis=1)
LinkedIn['tool_keywords'] = LinkedIn.apply(lambda row: count_skill_keywords(row['description'], tool_keywords1, tool_keywords2), axis=1)

# %%
LinkedIn = LinkedIn[['title','description', 'name', 'city','state' ,'min_salary', 'med_salary', 'max_salary', 'original_listed_time','skill_keywords', 'tool_keywords']]
fix_description_column_name= {
    'title': 'Title',
    'description': 'Description',
    'name': 'Company Name',
    'city': 'City',
    'state': 'State',
    'med_salary': 'Salary'

}



LinkedIn = LinkedIn.rename(columns=fix_description_column_name)
LinkedIn = LinkedIn.drop(['min_salary', 'max_salary', 'original_listed_time'], axis=1)

# Add new Year, Month, and Day columns
LinkedIn['Year'] = np.nan  
LinkedIn['Month'] = np.nan  
LinkedIn['Day'] = np.nan  

# Reorder columns
LinkedIn = LinkedIn[['Title', 'Description', 'Company Name', 'City', 'State', 'Salary','Year', 'Month', 'Day', 'skill_keywords', 'tool_keywords']]

# Drop rows that has either null, zero or empty in specified columns
LinkedIn = LinkedIn.dropna(subset=['Description', 'Salary', 'City', 'State'])
LinkedIn = LinkedIn[(LinkedIn['Description'] != '') & (LinkedIn['Salary'] != 0) & (LinkedIn['City'] != '')  & (LinkedIn['City'] != '0') &  (LinkedIn['State'] != '') & (LinkedIn['State'] != '0')]

LinkedIn['Salary'] = LinkedIn['Salary'].astype('float32').fillna(0).astype('int64')

# Save the modified DataFrame to a new CSV file
LinkedIn.to_csv('cleaned_LinkedIn.csv', index=False)

LinkedIn
# Out:
#                                     Title  \
# 0                   Hearing Care Provider
# 1                Patient Care Coordinator
# 5                                    Cook
# 6                              Dishwasher
# 7                       Custodian/Janitor
# ...                                   ...
# 32410          Agent Services Coordinator
# 32432                        Site Foreman
# 32433                           Estimator
# 32468         After School Academic Tutor
# 32495  Executive Administrative Assistant
#
#                                              Description  \
# 0      Overview  HearingLife is a national hearing ca...
# 1      Overview  Who WE Are:   HearingLife is a Deman...
# 5      descriptionTitle   Looking for a great opportu...
# 6      descriptionTitle   $2,000 Sign-on Bonus Guaran...
# 7      descriptionTitle  Come work as a Custodian at ...
# ...                                                  ...
# 32410  Are you enthusiastic about the world of reside...
# 32432  Site Crew Foreman The Procopio Companies (TPC)...
# 32433  EstimatorThe Procopio Companies (TPC) is a gro...
# 32468  Sterling House Community Center, Inc. Title: A...
# 32495  Position SummaryTogether Women Rise is a power...
#
#                                           Company Name        City  \
# 0                                          HearingLife    Somerset
# 1                                          HearingLife    Somerset
# 5                     Episcopal Communities & Services    Altadena
# 6                     Episcopal Communities & Services    Altadena
# 7                     Episcopal Communities & Services    Altadena
# ...                                                ...         ...
# 32410  The Steele Group Sotheby's International Realty     Henrico
# 32432                           The Procopio Companies   Middleton
# 32433                           The Procopio Companies   Middleton
# 32468             Sterling House Community Center Inc.   Stratford
# 32495                              Together Women Rise  Greenville
#
#                 State  Salary  Year  Month  Day  skill_keywords  tool_keywords
# 0          New Jersey   63000   NaN    NaN  NaN               1              2
# 1          New Jersey   63000   NaN    NaN  NaN               0              2
# 5          California   46321   NaN    NaN  NaN               0              0
# 6          California   40144   NaN    NaN  NaN               1              0
# 7          California   40144   NaN    NaN  NaN               1              0
# ...               ...     ...   ...    ...  ...             ...            ...
# 32410        Virginia   50000   NaN    NaN  NaN               0              1
# 32432   Massachusetts   24960   NaN    NaN  NaN               0              0
# 32433   Massachusetts   24960   NaN    NaN  NaN               1              0
# 32468     Connecticut   69867   NaN    NaN  NaN               0              0
# 32495  South Carolina   45760   NaN    NaN  NaN               0              0
#
# [1668 rows x 11 columns]
